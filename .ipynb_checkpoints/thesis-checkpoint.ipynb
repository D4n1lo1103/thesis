# %%
import json

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer

from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    log_loss,
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
tf.random.set_seed(RANDOM_STATE)

import os

output_dir = "graphics"

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %% [markdown]
# ## Data Preparation

# %%
with open("../export_db.json", encoding="utf-8") as f:
    data = json.load(f)

df = pd.DataFrame(data)
df.head()
# Out:
#     auction                 fishMarket    auctionType           gatherDate  \
# 0  2024.0.0  Mercato Ittico Giulianova  Dutch Auction  2026-03-02 00:00:00
# 1  2024.0.0  Mercato Ittico Giulianova  Dutch Auction  2026-03-02 00:00:00
# 2  2024.0.0  Mercato Ittico Giulianova  Dutch Auction  2026-03-02 00:00:00
# 3  2024.0.0  Mercato Ittico Giulianova  Dutch Auction  2026-03-02 00:00:00
# 4  2024.0.0  Mercato Ittico Giulianova  Dutch Auction  2026-03-02 00:00:00
#
#   schemaVersion dataCollector codice_azienda   cf_azienda piva_azienda  \
# 0         1.0.0          dump           M000  02121150672  02121150672
# 1         1.0.0          dump           M000  02121150672  02121150672
# 2         1.0.0          dump           M000  02121150672  02121150672
# 3         1.0.0          dump           M000  02121150672  02121150672
# 4         1.0.0          dump           M000  02121150672  02121150672
#
#                       ragione_sociale_azienda  ... famiglia_specie  \
# 0  Mercato Ittico Giulianova Soc. Cons. A.R.L  ...            TEST
# 1  Mercato Ittico Giulianova Soc. Cons. A.R.L  ...     Anguillidae
# 2  Mercato Ittico Giulianova Soc. Cons. A.R.L  ...     Nephropidae
# 3  Mercato Ittico Giulianova Soc. Cons. A.R.L  ...       Penaeidae
# 4  Mercato Ittico Giulianova Soc. Cons. A.R.L  ...      Eledonidae
#
#   identificazione_specie  descrizione_taglia unita_taglia  \
# 0                    000  SPECIE TEST GRANDE           10
# 1                    250              GRANDE           20
# 2                    565              GRANDE           20
# 3                    855              GRANDE            0
# 4                    256              GRANDE           20
#
#   vendibile_singolarmente progressivo_partita                        partita  \
# 0                       0                 2.0  ITA000000001/18.06.2025/00002
# 1                       0                 3.0  ITA000000001/18.06.2025/00003
# 2                       0                 4.0  ITA000000001/18.06.2025/00004
# 3                       0                 5.0  ITA000000001/18.06.2025/00005
# 4                       0                 6.0  ITA000000001/18.06.2025/00006
#
#   qualita_codice qualita_descrizione calibro_taglia_unita
# 0           Q001           I Qualità                   10
# 1           Q001           I Qualità                   20
# 2           Q001           I Qualità                   20
# 3           Q001           I Qualità                    0
# 4           Q001           I Qualità                   20
#
# [5 rows x 89 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19089 entries, 0 to 19088
# Data columns (total 84 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 19089 non-null  int64
#  1   codice_azienda                     19089 non-null  object
#  2   cf_azienda                         19089 non-null  object
#  3   piva_azienda                       19089 non-null  object
#  4   ragione_sociale_azienda            19089 non-null  object
#  5   indirizzo_legale_azienda           19089 non-null  object
#  6   codice_produttore                  19089 non-null  object
#  7   cf_produttore                      19089 non-null  object
#  8   piva_produttore                    19089 non-null  object
#  9   ragione_sociale_produttore         19089 non-null  object
#  10  indirizzo_legale_produttore        19089 non-null  object
#  11  codice_motopeschereccio            19088 non-null  object
#  12  nome_motopeschereccio              19088 non-null  object
#  13  targa_motopeschereccio             19088 non-null  object
#  14  numUE_motopeschereccio             19088 non-null  object
#  15  imo_motopeschereccio               16633 non-null  object
#  16  mmsi_motopeschereccio              16583 non-null  object
#  17  codice_sito_produttivo             1 non-null      object
#  18  nome_sito_produttivo               1 non-null      object
#  19  codice_metodo_produzione           1 non-null      object
#  20  descrizione_metodo_produzione      1 non-null      object
#  21  codice_acquirente                  19089 non-null  object
#  22  cf_acquirente                      19089 non-null  object
#  23  piva_acquirente                    19089 non-null  object
#  24  nome_acquirente                    19089 non-null  object
#  25  indirizzo_legale_acquirente        19018 non-null  object
#  26  codice_aspetto_imballo             19089 non-null  object
#  27  descrizione_aspetto_imballo        19089 non-null  object
#  28  tipo_aspetto_imballo               19089 non-null  object
#  29  tipo_imballo                       19089 non-null  object
#  30  descrizione_imballo                19089 non-null  object
#  31  peso_imballo                       19089 non-null  float64
#  32  codice_tipologia_lavorazione       19089 non-null  object
#  33  descrizione_tipologia_lavorazione  19089 non-null  object
#  34  lavorato                           19089 non-null  int64
#  35  data_vendita                       19089 non-null  object
#  36  modalita_acquisto                  19089 non-null  object
#  37  pesata_manuale                     19057 non-null  float64
#  38  numero_transazione                 19089 non-null  int64
#  39  codice_asta                        19089 non-null  object
#  40  numero_vendita                     19089 non-null  int64
#  41  codice_prodotto                    19089 non-null  object
#  42  nome_prodotto                      19089 non-null  object
#  43  descrizione_prodotto               19089 non-null  object
#  44  unita_misura                       19064 non-null  object
#  45  numero_casse                       19089 non-null  float64
#  46  extra_tara                         19089 non-null  float64
#  47  tara                               19089 non-null  float64
#  48  peso_netto                         19089 non-null  float64
#  49  peso_lordo                         19089 non-null  float64
#  50  divisa                             19057 non-null  object
#  51  stato_vendita                      19089 non-null  object
#  52  abbuono_peso                       19089 non-null  float64
#  53  lotto                              1 non-null      object
#  54  prezzo_unitario                    19089 non-null  float64
#  55  data_sbarco                        19018 non-null  object
#  56  prezzo_totale                      19089 non-null  float64
#  57  conservazione                      19089 non-null  object
#  58  ingredienti                        1 non-null      object
#  59  codice_attrezzatura                19089 non-null  object
#  60  descrizione_attrezzatura           19089 non-null  object
#  61  codice_GSA_zona                    19089 non-null  object
#  62  codice_presentazione               19089 non-null  object
#  63  descrizione_presentazione          19089 non-null  object
#  64  codice_stato_fisico                19089 non-null  object
#  65  descrizione_stato_fisico           19089 non-null  object
#  66  codice_freschezza                  19089 non-null  object
#  67  descrizione_freschezza             19089 non-null  object
#  68  codice_destinazione                19089 non-null  object
#  69  descrizione_destinazione           19089 non-null  object
#  70  codice_fao_specie                  19089 non-null  object
#  71  denominazione_specie               19089 non-null  object
#  72  denominazione_scientifica_specie   19089 non-null  object
#  73  ordine_specie                      19089 non-null  object
#  74  famiglia_specie                    19089 non-null  object
#  75  identificazione_specie             19086 non-null  object
#  76  descrizione_taglia                 19089 non-null  object
#  77  unita_taglia                       19089 non-null  int64
#  78  vendibile_singolarmente            19089 non-null  int64
#  79  progressivo_partita                19018 non-null  float64
#  80  partita                            19089 non-null  object
#  81  qualita_codice                     19089 non-null  object
#  82  qualita_descrizione                19089 non-null  object
#  83  calibro_taglia_unita               19089 non-null  int64
# dtypes: float64(11), int64(7), object(66)
# memory usage: 12.2+ MB

# %%
date_cols = ["data_vendita", "data_sbarco"]
for c in date_cols:
    if c in df.columns:
        df[c] = pd.to_datetime(df[c], errors="coerce")

selected_features = [
    "data_vendita",
    "modalita_acquisto",
    "peso_netto",
    "peso_lordo",
    "prezzo_unitario",
    "prezzo_totale",
    "codice_attrezzatura",
    "codice_GSA_zona",
    "codice_fao_specie",
    "data_sbarco",
    "qualita_codice"
]
df = df[[c for c in selected_features if c in df.columns]].copy()

# %%
missing_percentage = (df.isnull().mean() * 100).sort_values(ascending=False)
print(missing_percentage.head(10))
# Out:
# data_sbarco            0.371942
# modalita_acquisto      0.000000
# data_vendita           0.000000
# peso_netto             0.000000
# peso_lordo             0.000000
# prezzo_totale          0.000000
# prezzo_unitario        0.000000
# codice_attrezzatura    0.000000
# codice_GSA_zona        0.000000
# codice_fao_specie      0.000000
# dtype: float64

# %%
df = df.dropna(subset=["prezzo_unitario"]).copy()
df = df[df["prezzo_unitario"] >= 0]

if "peso_netto" in df.columns:
    df = df[df["peso_netto"].isna() | (df["peso_netto"] >= 0)]

if "peso_lordo" in df.columns:
    df = df[df["peso_lordo"].isna() | (df["peso_lordo"] >= 0)]

if "peso_lordo" in df.columns and "peso_netto" in df.columns:
    df = df[
        df["peso_lordo"].isna()
        | df["peso_netto"].isna()
        | (df["peso_lordo"] >= df["peso_netto"])
    ]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df['prezzo_unitario'].describe()
# Out:
# count    19089.000000
# mean         6.533539
# std          6.969224
# min          0.000000
# 25%          2.300000
# 50%          5.000000
# 75%          8.550000
# max        200.000000
# Name: prezzo_unitario, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["prezzo_unitario"], kde=True)
plt.title("Distribuzione del Prezzo Unitario")

plt.savefig(os.path.join(output_dir, "distribuzione_prezzo_unitario.png"), dpi=300)

plt.show()

# %%
plt.figure()
sns.boxplot(x=df["prezzo_unitario"])
plt.title("Boxplot del Prezzo Unitario")

plt.savefig(os.path.join(output_dir, "boxplot_prezzo_unitario.png"), dpi=300)

plt.show()

# %%
corr = df[[
    "peso_netto", "peso_lordo", 
    "prezzo_unitario", "prezzo_totale"
]].corr()

plt.figure()
sns.heatmap(corr, annot=True)
plt.title("Matrice di Correlazione")

plt.savefig(os.path.join(output_dir, "matrice_corr.png"), dpi=300)

plt.show()

# %%
selected_features.remove('peso_lordo')

# %%
df_time = df.dropna(subset=["data_vendita"]).copy()
df_time["Mese"] = df_time["data_vendita"].dt.month

monthly_price = df_time.groupby("Mese")["prezzo_unitario"].mean().sort_index()

plt.figure(figsize=(8,4))
plt.plot(monthly_price.index, monthly_price.values, marker="o")
plt.title("Prezzo Unitario Medio per Mese")
plt.xlabel("Mese")
plt.ylabel("Prezzo Unitario Medio")
plt.xticks(range(1,13))

plt.savefig(os.path.join(output_dir, "media_prezzo_mensile.png"), dpi=300)

plt.show()

monthly_price
# Out:
# Mese
# 6     27.890000
# 7     13.939320
# 8     12.757895
# 9      7.350344
# 10     5.931321
# 11     6.531087
# Name: prezzo_unitario, dtype: float64

# %% [markdown]
# ## Feature Engineering

# %%
df_fe = df.copy()

df_fe["Anno"] = df_fe["data_vendita"].dt.year
df_fe["Mese"] = df_fe["data_vendita"].dt.month
df_fe["Giorno_Settimana"] = df_fe["data_vendita"].dt.dayofweek

df_fe.head()
# Out:
#          data_vendita modalita_acquisto  peso_netto  peso_lordo  \
# 0 2025-06-19 13:31:40              SALA         8.7         9.0
# 1 2025-06-19 13:40:16              SALA         9.0         9.5
# 2 2025-06-19 13:59:30              SALA         9.7        10.0
# 3 2025-06-19 14:02:08              SALA         1.7         2.0
# 4 2025-06-19 15:59:27              SALA        10.0        10.5
#
#    prezzo_unitario  prezzo_totale codice_attrezzatura codice_GSA_zona  \
# 0             65.9         573.33                 OTB       37.2.1-18
# 1              8.5          76.50                 OTB       37.2.1-18
# 2             49.5         480.15                 OTB       37.2.1-18
# 3             26.6          45.22                 OTB       37.2.1-18
# 4              5.6          56.00                 OTB       37.2.1-18
#
#   codice_fao_specie data_sbarco qualita_codice  Anno  Mese  Giorno_Settimana
# 0               ZZZ  2025-06-18           Q001  2025     6                 3
# 1               ELE  2025-06-18           Q001  2025     6                 3
# 2               NEP  2025-06-18           Q001  2025     6                 3
# 3               TGS  2025-06-18           Q001  2025     6                 3
# 4               EOI  2025-06-18           Q001  2025     6                 3

# %%
df["prezzo_unitario_log"] = np.log1p(df["prezzo_unitario"])

plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
sns.histplot(df["prezzo_unitario"], kde=True)
plt.title("Distribuzione Prezzo Unitario")

plt.subplot(1,2,2)
sns.histplot(df["prezzo_unitario_log"], kde=True)
plt.title("Distribuzione Prezzo Unitario (log)")

plt.tight_layout()

plt.savefig(os.path.join(output_dir, "distribuzione_prezzo_unitario&log.png"), dpi=300)

plt.show()

# %% [markdown]
# ## Feed-Forward Neural Network

# %%
conteggio_transazioni = df['codice_fao_specie'].value_counts()
conteggio_transazioni
# Out:
# codice_fao_specie
# TGS    3513
# HKE    3060
# MTS    2742
# MUT    2055
# DPS    1262
#        ...
# ARY       1
# WEG       1
# OOA       1
# PAC       1
# UNG       1
# Name: count, Length: 152, dtype: int64

# %%
valori = ["TGS", "HKE", "MTS"]
df_NN = df[df["codice_fao_specie"].isin(valori)]

# %%
target_col = "codice_fao_specie"

X = df_NN.drop(columns=[target_col]).copy()

y_raw = df_NN[target_col].astype(str).copy()

# %%
le = LabelEncoder()

y = le.fit_transform(y_raw)

n_classes = len(le.classes_)

print("Classi:", list(le.classes_))
# Out:
# Classi: ['HKE', 'MTS', 'TGS']

# %%
num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
cat_cols = df.select_dtypes(exclude=[np.number]).columns.tolist()

# %%
def make_preprocess(X):
    num_cols = X.select_dtypes(include=[np.number]).columns.tolist()
    cat_cols = X.select_dtypes(exclude=[np.number]).columns.tolist()

    num_pipe = Pipeline([
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler())
    ])

    try:
        ohe = OneHotEncoder(handle_unknown="ignore", sparse_output=False)
    except TypeError:
        ohe = OneHotEncoder(handle_unknown="ignore", sparse=False)

    cat_pipe = Pipeline([
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("onehot", ohe)
    ])

    return ColumnTransformer([
        ("num", num_pipe, num_cols),
        ("cat", cat_pipe, cat_cols)
    ])

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=RANDOM_STATE
)

# %%
preprocess_nn = make_preprocess(X_train)
X_train_p = preprocess_nn.fit_transform(X_train).astype("float32")
X_test_p = preprocess_nn.transform(X_test).astype("float32")

# %%
model = keras.Sequential([
    layers.Input(shape=(X_train_p.shape[1],)),
    layers.Dense(256, activation="relu"),
    layers.Dropout(0.3),
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.2),
    layers.Dense(n_classes, activation="softmax")
])

# %%
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="sparse_categorical_crossentropy",  
    metrics=["accuracy"]
)

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",          
        patience=10,                 
        restore_best_weights=True    
    )
]

# %%
history = model.fit(
    X_train_p, y_train,
    validation_split=0.2,
    epochs=30,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8123 - loss: 0.5493 - val_accuracy: 0.8954 - val_loss: 0.3202
# Epoch 2/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9111 - loss: 0.2649 - val_accuracy: 0.9001 - val_loss: 0.2592
# Epoch 3/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9503 - loss: 0.1599 - val_accuracy: 0.9088 - val_loss: 0.2441
# Epoch 4/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9795 - loss: 0.0783 - val_accuracy: 0.9088 - val_loss: 0.2304
# Epoch 5/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9935 - loss: 0.0326 - val_accuracy: 0.9074 - val_loss: 0.2437
# Epoch 6/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9973 - loss: 0.0163 - val_accuracy: 0.9115 - val_loss: 0.2498
# Epoch 7/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9968 - loss: 0.0146 - val_accuracy: 0.9001 - val_loss: 0.2641
# Epoch 8/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9977 - loss: 0.0086 - val_accuracy: 0.8806 - val_loss: 0.3201
# Epoch 9/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9980 - loss: 0.0085 - val_accuracy: 0.8679 - val_loss: 0.3599
# Epoch 10/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9978 - loss: 0.0064 - val_accuracy: 0.8981 - val_loss: 0.2879
# Epoch 11/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9978 - loss: 0.0068 - val_accuracy: 0.9021 - val_loss: 0.3001
# Epoch 12/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9983 - loss: 0.0052 - val_accuracy: 0.8940 - val_loss: 0.3110
# Epoch 13/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9980 - loss: 0.0045 - val_accuracy: 0.8598 - val_loss: 0.3850
# Epoch 14/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9987 - loss: 0.0045 - val_accuracy: 0.9101 - val_loss: 0.2740

# %%
test_loss, test_acc = model.evaluate(X_test_p, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Test accuracy: 0.9082

# %%
y_proba = model.predict(X_test_p, verbose=0)   
y_pred = np.argmax(y_proba, axis=1)

# %%
print("\nClassification report:")
print(classification_report(y_test, y_pred, target_names=le.classes_))

print("\nConfusion matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#          HKE       0.86      0.89      0.88       612
#          MTS       0.96      0.90      0.93       548
#          TGS       0.91      0.93      0.92       703
#
#     accuracy                           0.91      1863
#    macro avg       0.91      0.91      0.91      1863
# weighted avg       0.91      0.91      0.91      1863
#
#
# Confusion matrix:
# [[544  15  53]
#  [ 39 495  14]
#  [ 46   4 653]]

# %% [markdown]
# ## Random Forest

# %%
df_RF = df.drop(columns=["prezzo_totale", "data_sbarco", "qualita_codice", "peso_lordo", "codice_attrezzatura", "modalita_acquisto", "data_vendita", "prezzo_unitario_log"], errors="ignore").copy()

X = df_RF.drop(columns=["prezzo_unitario"], errors="ignore")
y = df_RF["prezzo_unitario"].values

# %%
df_RF.head()
# Out:
#    peso_netto  prezzo_unitario codice_GSA_zona codice_fao_specie
# 0         8.7             65.9       37.2.1-18               ZZZ
# 1         9.0              8.5       37.2.1-18               ELE
# 2         9.7             49.5       37.2.1-18               NEP
# 3         1.7             26.6       37.2.1-18               TGS
# 4        10.0              5.6       37.2.1-18               EOI

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=RANDOM_STATE
)

# %%
preprocess_RF = make_preprocess(X_train)

RF = RandomForestRegressor(
    n_estimators=150,
    random_state=RANDOM_STATE,
    max_depth=20,
    n_jobs=-1
)

# %%
RF_model = Pipeline([
    ("preprocess", preprocess_RF),
    ("model", RF)
])

# %%
RF_model.fit(X_train, y_train)
y_pred = RF_model.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

# %%
print("\n--- Random Forest Regressor (Prezzo_Unitario €/kg) ---")
print(f"MAE : {mae:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"R^2 : {r2:.4f}")
# Out:
# --- Random Forest Regressor (Prezzo_Unitario €/kg) ---
# MAE : 2.4296
# RMSE: 4.4262
# R^2 : 0.5426
